# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
resumeRaw = "https://www.postjobfree.com/resumes?q=&l=New+York+City%2C+NY&radius=25"

# %%
page = requests.get(resumeRaw)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
def resumeURLs(base):
    resume_base = "https://www.postjobfree.com/resume"
    temp = soup.find_all("div", {"class": "snippetPadding"})

# %%
resume_list = soup.find_all("div", {"class": "snippetPadding"})

# %%
resume_list
# Out:
# []

# %%
url_base = "https://www.postjobfree.com/resume"

# %%
temp = resume_list[1].find_all('a')[0].get('href')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-7c24f91f65ff> in <module>
# ----> 1 temp = resume_list[1].find_all('a')[0].get('href')
#
# IndexError: list index out of range

# %%
temp
# Out:
# '/resume/adw3pj/event-coordinator-manager-brooklyn-ny'

# %%
url_base + temp
# Out:
# 'https://www.postjobfree.com/resume/resume/adw3pj/event-coordinator-manager-brooklyn-ny'

# %%
page = requests.get(url_base + temp)

# %%
soup2 = BeautifulSoup(page.content, "html.parser")

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><title>
# 	404 Page Not found
# </title>
# <style>
# .stdContentLayout { max-width:750px; margin:auto; }
# html, body {
# 	height:100%;
# }
# body {
# 	margin:0;
# 	padding:0;
# 	display:flex;
# 	flex-direction:column;
# }
# footer {
# 	height:35px;
# 	margin-top:auto;
# }
# .fbar {
# 	font-size:small;
# 	background:#f2f2f2;
# 	border-top:1px solid #e4e4e4;
# 	line-height:34px;
# 	text-align:center;
# }
# .fbar a {white-space:nowrap;}
# footer .fbar a {color:#555;}
# .fe {
# 	margin-left:15px;
# 	margin-right:15px;
# }
# </style>
# <style>
# 	.headerMenuMargin { margin-right:15px; }
# 	@media screen and (min-width: 750px) {
# 		.headerMenuMargin { margin-right:20px; }
# 	}
# </style></head>
# <body>
# <div>
# ...

# %%
# !pip3 install youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
srt = YouTubeTranscriptApi.get_transcript("7vEG5OCcWtg")

# %%
text = ''

# %%
for i in srt:
    text += i['text'] + " "

# %%
text
# Out:
# "foreign [Music] [Music] [Music] hello everyone welcome back to the channel [Music] um on a scale of one to ten how needy are you a hundred [Applause] do you guys want to see my green onion that I am growing these ones are pretty new not mine what I'm gonna do right now is finish up putting up the curtains [Music] [Applause] [Music] again these tracks have the 3M sticker in the back so it's really easy to just and no drilling required and the sun's coming out again I don't know what it is but Dobby has been so anxious look at the separation anxiety has just it's gotten out of control since moving to the new place I have not left him home alone I probably ate out once since I moved here I've just been at home all day every day I cannot leave Dobby alone I have not even explored the neighborhood tried any of the food because my son has really bad separation anxiety [Music] thank you [Applause] [Music] for dinner today I am making which is braised chicken [Music] [Music] [Applause] [Mus
# ...

# %%
url = 'https://www.youtube.com/watch?v=nV8UZJNBY6Y'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
soup.find_all("body", attrs= {"dir":"ltr"})
# Out:
# [<body dir="ltr" no-y-overflow=""><script nonce="B8XSL5MqkmyOYHJFebymOQ">var ytInitialPlayerResponse = {"responseContext":{"serviceTrackingParams":[{"service":"GFEEDBACK","params":[{"key":"is_viewed_live","value":"False"},{"key":"is_alc_surface","value":"false"},{"key":"ipcc","value":"0"},{"key":"logged_in","value":"0"},{"key":"e","value":"9407155,23804281,23918597,23946420,23966208,23983296,23998056,24004644,24007246,24007613,24034168,24036948,24077241,24080738,24120820,24135310,24140247,24166867,24181174,24187043,24187377,24211178,24219713,24224266,24228638,24241378,24255543,24255545,24262346,24288664,24290971,24291857,24299873,24362099,24390675,24391689,24403793,24404640,24405914,24407191,24409417,24414720,24415864,24428789,24429093,24433679,24437577,24439361,24440132,24440518,24440520,24450131,24451319,24453989,24455284,24456653,24457383,24458317,24458324,24458329,24458839,24459435,24465011,24466371,24468691,24468724,24470719,24471752,24481175,24483503,24485239,24485421,24488188,
# ...

# %%
soup.find("body").find("ytd_app")
